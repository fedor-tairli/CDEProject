# %%
import torch
import numpy

# %%
IDs = torch.load('AllEventIds.pt')

# %%
if type(IDs)==torch.tensor:IDs = IDs.numpy()

# %%
for ID in numpy.unique(IDs):
    count = numpy.count_nonzero(IDs==ID)
    print(f'For Id {ID} there are {count} events')
# Out:
# For Id 100000101 there are 16 events
# For Id 100000102 there are 16 events
# For Id 100000103 there are 16 events
# For Id 100000104 there are 16 events
# For Id 100000105 there are 16 events
# For Id 100000106 there are 8 events
# For Id 100000107 there are 8 events
# For Id 100000108 there are 8 events
# For Id 100000109 there are 8 events
# For Id 100000110 there are 8 events
# For Id 100000111 there are 4 events
# For Id 100000112 there are 4 events
# For Id 100000113 there are 4 events
# For Id 100000114 there are 4 events
# For Id 100000115 there are 4 events
# For Id 100000116 there are 4 events
# For Id 100000117 there are 4 events
# For Id 100000118 there are 4 events
# For Id 100000119 there are 4 events
# For Id 100000120 there are 4 events
# For Id 100000121 there are 4 events
# For Id 100000122 there are 4 events
# For Id 100000123 there are 4 events
# For Id 100000124 there are 4 events
# For Id 100000125 there are 4 events
# For Id 100000126 there are 4 events
# ...
