# %%
import difflib

# %%
with open('recDataKeys.txt','r') as file1, open('recDataKeysWanted.txt','r') as file2:
    allKeys=file1.readlines()
    wantedKeys=file2.readlines()

# %%
unwantedKeys = [x for x in allKeys if x not in wantedKeys]

# %%
for key in unwantedKeys:
    print(key.split('/')[-1],end='')
# Out:
# event.
# event.TObject
# event.TObject.fUniqueID
# event.TObject.fBits
# event.fDetector.TObject
# event.fDetector.fUniqueID
# event.fDetector.fBits
# event.fDetector.fActiveStations.TObject
# event.fDetector.fActiveStations.fUniqueID
# event.fDetector.fActiveStations.fBits
# event.fDetector.fActiveStations.fNbits
# event.fDetector.fActiveStations.fNbytes
# event.fDetector.fActiveStations.fAllBits
# event.fDetector.fActiveEyes.TObject
# event.fDetector.fActiveEyes.fUniqueID
# event.fDetector.fActiveEyes.fBits
# event.fDetector.fActiveEyes.fNbits
# event.fDetector.fActiveEyes.fNbytes
# event.fDetector.fActiveEyes.fAllBits
# event.fDetector.fTelDAQBits
# event.fDetector.fSDFDTimeOffset
# event.fDetector.fSDFDTimeOffset.first
# event.fDetector.fSDFDTimeOffset.second
# event.fDetector.fCorrectorRingStatus
# event.fDetector.fVAODs
# event.fDetector.fVAODs.first
# event.fDetector.fVAODs.second
# event.fDetector.fMismatchedPixels
# event.fDetector.fBadPixels
# ...
